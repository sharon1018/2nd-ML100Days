# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import copy, time
from IPython.display import display
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

data_path = 'data/'
df_train_x = pd.read_csv(data_path + 'train.csv', header=None)
df_train_y = pd.read_csv(data_path + 'trainLabels.csv', header=None)
df_test_x = pd.read_csv(data_path + 'test.csv', header=None)

# %%
df_train_x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          7         8         9   ...        30        31        32        33  \
# 0  1.594506 -0.051608  0.663234  ... -0.850465 -0.622990 -1.833057  0.293024
# 1  2.619246 -0.765884 -0.093780  ... -0.819750  0.012037  2.038836  0.468579
# 2 -4.219054 -1.184919 -1.240310  ... -0.604501  0.750054 -3.360521  0.856988
# 3  4.499666  1.038741 -1.092716  ...  1.022959  1.275598 -3.480110 -1.065252
# 4 -4.290282 -1.761308  0.807652  ...  0.513906 -1.803473  0.518579 -0.205029
#
#          34        35        36        37        38        39
# 0  3.552681  0.717611  3.305972 -2.715559 -2.682409  0.101050
# 1 -0.517657  0.422326  0.803699  1.213219  1.382932 -1.817761
# 2 -2.751451 -1.582735  1.672246  0.656438 -0.932473  2.987436
# 3  2.153133  1.563539  2.767117  0.215748  0.619645  1.883397
# 4 -4.744566 -1.520015  1.830651  0.870772 -1.894609  0.408332
#
# [5 rows x 40 columns]

# %%
train_x, test_x, train_y, test_y = train_test_split(df_train_x, df_train_y, test_size = 0.1)

model = GradientBoostingClassifier()

model.fit(train_x, train_y)

pred_y = model.predict(test_x)

accuracy = metrics.accuracy_score(test_y, pred_y)
print(f'accuracy = {accuracy}')
# Out:
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy = 0.84

# %%
result = set()
for i in range(10):
    n_estimators = np.random.randint(100, 500, size=10)
    max_depth = np.random.randint(1, 20, size=10)

    param_grid = dict(n_estimators=n_estimators, max_depth=max_depth)

    grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, verbose=2)

    grid_result = grid_search.fit(train_x, train_y)
    
    candidate = (grid_result.best_params_['n_estimators'], grid_result.best_params_['max_depth'])
    
    result.add(candidate)
    
    print(f'Best Accuracy: {grid_result.best_score_} using {grid_result.best_params_}')
# Out:
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.6min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.88 using {'max_depth': 6, 'n_estimators': 143}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.7min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8666666666666667 using {'max_depth': 3, 'n_estimators': 482}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.6min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8788888888888889 using {'max_depth': 6, 'n_estimators': 278}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.7min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8777777777777778 using {'max_depth': 6, 'n_estimators': 370}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.7min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.87 using {'max_depth': 4, 'n_estimators': 193}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.9min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8722222222222222 using {'max_depth': 4, 'n_estimators': 229}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.7min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.87 using {'max_depth': 4, 'n_estimators': 200}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.7min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8711111111111111 using {'max_depth': 4, 'n_estimators': 169}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.6min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8644444444444445 using {'max_depth': 3, 'n_estimators': 455}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# c:\users\asus\new_env\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.8min finished
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy: 0.8755555555555555 using {'max_depth': 6, 'n_estimators': 196}

# %%
model = GradientBoostingClassifier(n_estimators=196, max_depth=6)

model.fit(train_x, train_y)

pred_y = model.predict(test_x)

accuracy = metrics.accuracy_score(test_y, pred_y)
print(f'accuracy = {accuracy}')
# Out:
# c:\users\asus\new_env\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy = 0.9

# %%
pred_test_y = model.predict(df_test_x)

df_pred_test_y = pd.DataFrame(pred_test_y)

df_pred_test_y.columns = ['Solution']
df_pred_test_y['Id'] = np.arange(1, df_pred_test_y.shape[0]+1)
df_pred_test_y = df_pred_test_y[['Id', 'Solution']]

df_pred_test_y.to_csv('sklearn_baseline.csv', index=False) 

df_pred_test_y
# Out:
#         Id  Solution
# 0        1         1
# 1        2         0
# 2        3         1
# 3        4         0
# 4        5         0
# ...    ...       ...
# 8995  8996         1
# 8996  8997         1
# 8997  8998         1
# 8998  8999         0
# 8999  9000         1
#
# [9000 rows x 2 columns]
